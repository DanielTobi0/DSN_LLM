# %% [markdown]
# ## Joint Probability
#
# Joint probability refers to the likelihood of two events occurring at the same time.
#
# It's the probability that both events happen together.
#
# Mathematically, the joint probability of two events
# 𝐴
# A and
# 𝐵
# B is written as:
#
# 𝑃
# (
# 𝐴
# ∩
# 𝐵
# )
# =
# 𝑃
# (
# 𝐴
#  and
# 𝐵
# )
# P(A∩B)=P(A and B)
#
# This is read as "the probability that event
# 𝐴
# A occurs and event
# 𝐵
# B occurs."
#
# For example, if you roll two dice, the joint probability of getting a 4 on the first die and a 3 on the second die is the probability of both of these happening together.

# %% [markdown]
# ## Conditional Probability
#
#
# Conditional probability is the probability of an event happening, given that another event has already occurred.
#
# It's a way of refining the probability when you have more information.
#
#
# The conditional probability of
# 𝐴
# A occurring given that
#
# 𝐵
# B has occurred is written as:
#
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐴
# ∩
# 𝐵
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(A∩B)
# ​
#
# where
# 𝑃
# (
# 𝐴
# ∩
# 𝐵
# )
# P(A∩B) is the joint probability of both
# 𝐴
# A and
# 𝐵
# B happening, and
# 𝑃
# (
# 𝐵
# )
# P(B) is the probability that
# 𝐵
# B happens.
#
# For example, if you have a deck of cards and you know the card drawn is a spade, the probability that it's the Ace of Spades (given it's a spade) is conditional probability.

# %% [markdown]
# ## Bayes' Rule
#
# Bayes' Rule is a powerful tool in probability theory that allows you to update the probability of an event based on new information. It relates conditional probabilities in the reverse direction: it helps to find the probability of an event
#
# 𝐴
# A given
# 𝐵
# B has occurred, using the reverse (i.e.,
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A)) and other known values.
#
# Bayes' Rule is written as:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) is the probability of event
# 𝐴
# A happening given that
# 𝐵
# B has occurred (the posterior probability).
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) is the probability of event
# 𝐵
# B happening given that
# 𝐴
# A has occurred (the likelihood).
#
# 𝑃
# (
# 𝐴
# )
# P(A) is the prior probability of event
# 𝐴
# A.
#
# 𝑃
# (
# 𝐵
# )
# P(B) is the probability of event
# 𝐵
# B.
#
# This is often used for decision-making and inference when you need to revise probabilities as new evidence is available.
#
# Example of Bayes' Rule:
# Suppose there's a medical test for a disease:
#
# The probability of having the disease is
#
# 𝑃
# (
# Disease
# )
# =
# 0.01
# P(Disease)=0.01.
#
# The probability that a person without the disease tests positive (false positive rate) is
#
# 𝑃
# (
# Positive Test
# ∣
# No Disease
# )
# =
# 0.05
# P(Positive Test∣No Disease)=0.05.
#
# The probability that a person with the disease tests positive (true positive rate) is
#
# 𝑃
# (
# Positive Test
# ∣
# Disease
# )
# =
# 0.95
# P(Positive Test∣Disease)=0.95.
#
# Now, if someone tests positive, Bayes' Rule helps calculate the probability that they actually have the disease.

# %% [markdown]
# ## In summary:
#
# Joint Probability looks at the likelihood of two events happening together.
#
# Conditional Probability is the probability of an event, given that another event has occurred.
#
# Bayes' Rule helps you update your beliefs or probability estimates when new evidence is available.

# %%
https://www.youtube.com/watch?v=4vmiaA3Qt4Y
